# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %%
print(cities)
# Out:
# ['attawapiskat', 'pisco', 'uinskoye', 'cap-aux-meules', 'dikson', 'port elizabeth', 'tasiilaq', 'punta arenas', 'hobart', 'belushya guba', 'kavieng', 'maragogi', 'maanshan', 'coquimbo', 'carnarvon', 'hermanus', 'austin', 'albany', 'ushuaia', 'sambava', 'bethel', 'sitka', 'taolanaro', 'back mountain', 'kathu', 'churachandpur', 'ostrovnoy', 'hilo', 'umm durman', 'new norfolk', 'porto novo', 'yumen', 'butaritari', 'khatanga', 'sentyabrskiy', 'srednekolymsk', 'temba', 'dubno', 'lorengau', 'bluff', 'saint anthony', 'puerto narino', 'tomatlan', 'lagoa', 'illoqqortoormiut', 'chuy', 'petropavlovsk-kamchatskiy', 'fortuna', 'maple creek', 'svetlaya', 'enger', 'kahului', 'taltal', 'lompoc', 'lebane', 'cape town', 'poum', 'zudilovo', 'avarua', 'mataura', 'ust-maya', 'lebu', 'barrow', 'umzimvubu', 'san matias', 'saint-philippe', 'victoria', 'lensk', 'vaini', 'seminole', 'codrington', 'gustavo diaz ordaz', 'port alfred', 'lasa', 'todos santos', 'hirara', 'tancheng', 'bilma', 'bredasdorp', 'georgetown', 'bansgaon', 'provideniya', 'mys shmidta', 'nguiu', 'puerto ayora', 'longyearbyen', 'rikitea', 'san policarpo', 'berlevag', 'makat', 'imamoglu', 'castro', 'saint-francois', 'ereymentau', 'talnakh', 'iqaluit', 'dublin', 'nizhneyansk', 'papar', 'grand river south east', 'giovinazzo', 'atambua', 'chapais', 'pangoa', 'beringovskiy', 'severo-kurilsk', 'merauke', 'komsomolskiy', 'oboyan', 'bosaso', 'la reforma', 'paciran', 'torgelow', 'loa janan', 'qaanaaq', 'kegayli', 'esperance', 'thompson', 'sarkand', 'ingham', 'kapaa', 'ponta do sol', 'atuona', 'sorland', 'nikolskoye', 'busselton', 'itarema', 'southampton', 'panacan', 'strezhevoy', 'east london', 'tual', 'valdivia', 'balkanabat', 'tumannyy', 'hasaki', 'wyndham', 'san pedro de ycuamandiyu', 'guerrero negro', 'upernavik', 'caronport', 'sakakah', 'san patricio', 'barentsburg', 'mokhsogollokh', 'olafsvik', 'asnaes', 'aklavik', 'mar del plata', 'lavrentiya', 'balikpapan', 'ponerihouen', 'leningradskiy', 'mama', 'ahipara', 'kamenka', 'cosala', 'bathsheba', 'quatre cocos', 'airai', 'haines junction', 'north bend', 'monte cristi', 'cherskiy', 'trelleborg', 'rio gallegos', 'fomboni', 'arsk', 'yellowknife', 'saskylakh', 'iberia', 'arraial do cabo', 'rawson', 'romitan', 'buin', 'deputatskiy', 'faya', 'marawi', 'kruisfontein', 'avera', 'khandela', 'guangyuan', 'takab', 'guilin', 'urengoy', 'hithadhoo', 'la joya', 'luderitz', 'norman wells', 'qorveh', 'chokurdakh', 'alice springs', 'isangel', 'shaoyang', 'jamestown', 'kodiak', 'palmer', 'artesia', 'meyungs', 'rundu', 'pringsewu', 'golspie', 'bengkulu', 'faanui', 'dickinson', 'hambantota', 'mahebourg', 'carutapera', 'cockburn town', 'urucara', 'dalbandin', 'tuatapere', 'nanortalik', 'bambous virieux', 'morondava', 'palana', 'revda', 'kota tinggi', 'saint george', 'souillac', 'karaul', 'klaksvik', 'astana', 'cidreira', 'cavalcante', 'abha', 'narsaq', 'zhigansk', 'redmond', 'okitipupa', 'port lincoln', 'yakeshi', 'laguna', 'shirokiy', 'luanda', 'san luis', 'caxito', 'jumla', 'tuensang', 'college', 'naryan-mar', 'nuuk', 'santa marta', 'alofi', 'guanare', 'paamiut', 'sur', 'apastepeque', 'maniitsoq', 'mitsamiouli', 'rungata', 'moroni', 'shaowu', 'tyup', 'slupca', 'muros', 'aosta', 'mareeba', 'springbok', 'perm', 'broome', 'lhokseumawe', 'george town', 'ilulissat', 'celestun', 'awjilah', 'gizo', 'nome', 'sao felix do xingu', 'richards bay', 'portland', 'beloha', 'villa maria', 'tsihombe', 'toppenish', 'vieste', 'kharp', 'smidovich', 'mayor pablo lagerenza', 'amderma', 'derzhavinsk', 'mutare', 'cayenne', 'constitucion', 'sao joao da barra', 'husavik', 'kem', 'tautira', 'brazzaville', 'san andres', 'saldanha', 'batagay', 'altay', 'nerchinskiy zavod', 'ancud', 'ustyuzhna', 'lesnoy', 'umba', 'kununurra', 'watertown', 'salalah', 'tarudant', 'oyama', 'waipawa', 'galeana', 'cabo san lucas', 'port hedland', 'zlobin', 'ovruch', 'los llanos de aridane', 'touros', 'port macquarie', 'saint-pierre', 'tarnowskie gory', 'te anau', 'katsuura', 'erenhot', 'floro', 'kirakira', 'ave ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create settings dictionary with information we're interested in
settings = {"units": "metric", "appid": api_key}

current_weather = {}
for city in cities: 
    try:
        current_city = owm.get_current(city, **settings)
        current_weather[city] = current_city
        print(f'Processing {city}')
    except:
        print(f'{city} does not exist')



# Get current weather
# current_weather_paris = owm.get_current("Paris", **settings)
# print(current_weather_paris)
# Out:
# attawapiskat does not exist
# Processing pisco
# Processing uinskoye
# Processing cap-aux-meules
# Processing dikson
# Processing port elizabeth
# Processing tasiilaq
# Processing punta arenas
# Processing hobart
# belushya guba does not exist
# Processing kavieng
# Processing maragogi
# Processing maanshan
# Processing coquimbo
# Processing carnarvon
# Processing hermanus
# Processing austin
# Processing albany
# Processing ushuaia
# Processing sambava
# Processing bethel
# Processing sitka
# taolanaro does not exist
# Processing back mountain
# Processing kathu
# Processing churachandpur
# Processing ostrovnoy
# Processing hilo
# umm durman does not exist
# Processing new norfolk
# Processing porto novo
# Processing yumen
# Processing butaritari
# Processing khatanga
# sentyabrskiy does not exist
# Processing srednekolymsk
# Processing temba
# Processing dubno
# Processing lorengau
# Processing bluff
# Processing saint anthony
# Processing puerto narino
# Processing tomatlan
# Processing lagoa
# illoqqortoormiut does not exist
# Processing chuy
# Processing petropavlovsk-kamchatskiy
# Processing fortuna
# Processing maple creek
# Processing svetlaya
# Processing enger
# Processing kahului
# Processing taltal
# Processing lompoc
# Processing lebane
# Processing cape town
# Processing poum
# Processing zudilovo
# Processing avarua
# Processing mataura
# Processing ust-maya
# Processing lebu
# Processing barrow
# umzimvubu does not exist
# Processing san matias
# Processing saint-philippe
# Processing victoria
# Processing lensk
# Processing vaini
# Processing seminole
# Processing codrington
# Processing gustavo diaz ordaz
# Processing port alfred
# Processing lasa
# Processing todos santos
# Processing hirara
# Processing tancheng
# Processing bilma
# Processing bredasdorp
# Processing georgetown
# Processing bansgaon
# Processing provideniya
# mys shmidta does not exist
# nguiu does not exist
# Processing puerto ayora
# Processing longyearbyen
# Processing rikitea
# Processing san policarpo
# Processing berlevag
# Processing makat
# Processing imamoglu
# Processing castro
# Processing saint-francois
# Processing ereymentau
# Processing talnakh
# Processing iqaluit
# Processing dublin
# nizhneyansk does not exist
# Processing papar
# grand river south east does not exist
# Processing giovinazzo
# Processing atambua
# Processing chapais
# Processing pangoa
# Processing beringovskiy
# Processing severo-kurilsk
# Processing merauke
# Processing komsomolskiy
# Processing oboyan
# Processing bosaso
# Processing la reforma
# Processing paciran
# Processing torgelow
# Processing loa janan
# Processing qaanaaq
# kegayli does not exist
# Processing esperance
# Processing thompson
# Processing sarkand
# Processing ingham
# Processing kapaa
# Processing ponta do sol
# Processing atuona
# Processing sorland
# Processing nikolskoye
# Processing busselton
# Processing itarema
# Processing southampton
# Processing panacan
# Processing strezhevoy
# Processing east london
# Processing tual
# Processing valdivia
# Processing balkanabat
# tumannyy does not exist
# Processing hasaki
# Processing wyndham
# Processing san pedro de ycuamandiyu
# Processing guerrero negro
# Processing upernavik
# Processing caronport
# sakakah does not exist
# Processing san patricio
# barentsburg does not exist
# Processing mokhsogollokh
# olafsvik does not exist
# Processing asnaes
# Processing aklavik
# Processing mar del plata
# Processing lavrentiya
# Processing balikpapan
# Processing ponerihouen
# Processing leningradskiy
# Processing mama
# Processing ahipara
# Processing kamenka
# cosala does not exist
# Processing bathsheba
# Processing quatre cocos
# Processing airai
# Processing haines junction
# Processing north bend
# monte cristi does not exist
# Processing cherskiy
# Processing trelleborg
# Processing rio gallegos
# Processing fomboni
# Processing arsk
# Processing yellowknife
# Processing saskylakh
# Processing iberia
# Processing arraial do cabo
# Processing rawson
# Processing romitan
# Processing buin
# Processing deputatskiy
# Processing faya
# Processing marawi
# Processing kruisfontein
# Processing avera
# Processing khandela
# Processing guangyuan
# Processing takab
# Processing guilin
# Processing urengoy
# Processing hithadhoo
# Processing la joya
# Processing luderitz
# Processing norman wells
# Processing qorveh
# Processing chokurdakh
# Processing alice springs
# Processing isangel
# Processing shaoyang
# Processing jamestown
# Processing kodiak
# Processing palmer
# Processing artesia
# meyungs does not exist
# Processing rundu
# Processing pringsewu
# Processing golspie
# bengkulu does not exist
# Processing faanui
# Processing dickinson
# Processing hambantota
# Processing mahebourg
# Processing carutapera
# Processing cockburn town
# Processing urucara
# Processing dalbandin
# Processing tuatapere
# Processing nanortalik
# Processing bambous virieux
# Processing morondava
# Processing palana
# Processing revda
# Processing kota tinggi
# Processing saint george
# Processing souillac
# karaul does not exist
# Processing klaksvik
# Processing astana
# Processing cidreira
# Processing cavalcante
# Processing abha
# Processing narsaq
# Processing zhigansk
# Processing redmond
# Processing okitipupa
# Processing port lincoln
# Processing yakeshi
# Processing laguna
# Processing shirokiy
# Processing luanda
# Processing san luis
# Processing caxito
# Processing jumla
# Processing tuensang
# Processing college
# Processing naryan-mar
# Processing nuuk
# Processing santa marta
# Processing alofi
# Processing guanare
# Processing paamiut
# Processing sur
# Processing apastepeque
# Processing maniitsoq
# Processing mitsamiouli
# rungata does not exist
# Processing moroni
# Processing shaowu
# Processing tyup
# Processing slupca
# Processing muros
# Processing aosta
# Processing mareeba
# Processing springbok
# Processing perm
# Processing broome
# Processing lhokseumawe
# Processing george town
# Processing ilulissat
# Processing celestun
# Processing awjilah
# Processing gizo
# Processing nome
# Processing sao felix do xingu
# Processing richards bay
# Processing portland
# Processing beloha
# Processing villa maria
# tsihombe does not exist
# Processing toppenish
# Processing vieste
# Processing kharp
# Processing smidovich
# Processing mayor pablo lagerenza
# amderma does not exist
# Processing derzhavinsk
# Processing mutare
# Processing cayenne
# Processing constitucion
# Processing sao joao da barra
# Processing husavik
# Processing kem
# Processing tautira
# Processing brazzaville
# Processing san andres
# Processing saldanha
# Processing batagay
# Processing altay
# Processing nerchinskiy zavod
# Processing ancud
# Processing ustyuzhna
# Processing lesnoy
# Processing umba
# Processing kununurra
# Processing watertown
# Processing salalah
# tarudant does not exist
# Processing oyama
# Processing waipawa
# Processing galeana
# Processing cabo san lucas
# Processing port hedland
# Processing zlobin
# Processing ovruch
# Processing los llanos de aridane
# Processing touros
# Processing port macquarie
# Processing saint-pierre
# Processing tarnowskie gory
# Processing te anau
# Processing katsuura
# Processing erenhot
# Processing floro
# Processing kirakira
# Processing avesta
# Processing valledupar
# Processing margate
# Processing waingapu
# kyra does not exist
# Processing lincoln
# Processing cabral
# Processing oxbow
# Processing bouar
# Processing bubaque
# Processing shingu
# Processing san quintin
# Processing aksu
# Processing dicabisagan
# Processing clyde river
# Processing torbay
# Processing salta
# inderborskiy does not exist
# Processing ciudad bolivar
# Processing vila franca do campo
# Processing mosetse
# Processing joshimath
# Processing krasnoarmeysk
# Processing luis correia
# Processing carthage
# Processing padang
# Processing matara
# Processing talara
# Processing scarborough
# Processing ayan
# Processing coalinga
# Processing ailigandi
# Processing port-gentil
# Processing poya
# Processing limbang
# Processing daru
# Processing norsup
# Processing khor
# Processing tuktoyaktuk
# Processing fairbanks
# Processing peleduy
# Processing manggar
# Processing kirensk
# Processing tessalit
# vaitupu does not exist
# Processing alta floresta
# Processing samarai
# Processing kaspiyskiy
# Processing uige
# Processing necochea
# Processing vardo
# Processing payson
# Processing puerto escondido
# Processing goderich
# Processing burias
# saleaula does not exist
# Processing orbetello
# Processing havoysund
# sembe does not exist
# Processing lac du bonnet
# bac lieu does not exist
# Processing progreso
# Processing san joaquin
# Processing geraldton
# Processing trinidad
# Processing karratha
# Processing port blair
# Processing catalao
# Processing tema
# Processing morant bay
# Processing vao
# Processing zhob
# Processing paptalaya
# Processing burnie
# Processing shancheng
# Processing male
# samalaeulu does not exist
# Processing oranjemund
# Processing nampula
# Processing lujan
# Processing grants pass
# Processing oranjestad
# Processing wanning
# Processing babstovo
# westpunt does not exist
# Processing najran
# Processing vila velha
# Processing qianjiang
# Processing sibolga
# Processing hohhot
# Processing anadyr
# Processing mangulile
# Processing nhulunbuy
# Processing rocha
# Processing makakilo city
# Processing winnemucca
# Processing dauphin
# Processing jardim
# Processing bambanglipuro
# yingzhong does not exist
# Processing porbandar
# Processing west bay
# Processing ouargaye
# Processing kamaishi
# Processing akdepe
# Processing nelson bay
# Processing kavaratti
# Processing mehamn
# Processing buchanan
# Processing lemery
# Processing porto belo
# Processing san cristobal
# Processing mekhe
# Processing clarksville
# Processing ovalle
# Processing merke
# Processing santa vitoria
# Processing baghmara
# Processing tura
# Processing general roca
# Processing flin flon
# rolim de moura does not exist
# paradwip does not exist
# Processing fukue
# Processing conde
# Processing abu dhabi
# Processing almaznyy
# Processing dalvik
# Processing ngunguru
# Processing flinders
# Processing vung tau
# Processing bandarbeyla
# Processing grado
# Processing prainha
# Processing teya
# Processing nizhniy kuranakh
# Processing bainbridge
# Processing broken hill
# Processing kenai
# Processing sao filipe
# Processing port hardy
# Processing kaitangata
# Processing namatanai
# Processing pasighat
# Processing pevek
# Processing udachnyy
# Processing cap malheureux
# Processing gbarnga
# Processing solnechnyy
# Processing vohma
# Processing san francisco
# Processing racine
# Processing hofn
# Processing san javier
# Processing brigantine
# tukrah does not exist
# Processing nalut
# Processing wasilla
# Processing sao jose da coroa grande
# Processing stokmarknes
# Processing vostok
# Processing charters towers
# Processing macapa
# Processing port-cartier
# marcona does not exist
# Processing morrope
# Processing biri
# Processing carinhanha
# Processing darhan
# Processing akonolinga
# Processing abu samrah
# Processing shaunavon
# Processing plettenberg bay
# Processing nemuro
# Processing barranco
# Processing cabedelo
# Processing kaeo
# Processing nedryhayliv
# Processing khandyga
# Processing launceston
# Processing kulhudhuffushi
# Processing eyl
# Processing noumea
# Processing okakarara
# Processing lata
# Processing malanje
# urumqi does not exist
# Processing fort nelson
# Processing letnyaya stavka
# Processing keti bandar
# Processing sal rei
# kawana waters does not exist
# Processing diebougou
# samusu does not exist
# Processing gazimurskiy zavod
# Processing vestmannaeyjar
# Processing botwood
# Processing ribeira grande
# Processing chernyshevskiy
# Processing dzilam gonzalez
# Processing ginda
# Processing marsh harbour
# Processing mabaruma
# seinajoki does not exist
# Processing casa nova
# Processing ibotirama
# Processing kibondo
# Processing chimbarongo
# Processing pacific grove
# Processing mount gambier
# Processing novorzhev
# Processing khromtau
# Processing tiznit
# Processing luau
# Processing mushie
# Processing halvad
# Processing praia
# Processing muroto
# Processing gandajika
# Processing kyshtovka
# Processing labuhan
# Processing bolotnoye
# Processing ghosi
# Processing putina
# Processing wildeshausen
# Processing batouri
# mrirt does not exist
# Processing kropotkin
# Processing konstantinovka
# Processing auki
# Processing mumford
# Processing nioro
# kuche does not exist
# Processing nogales
# Processing dudinka
# x-can does not exist
# Processing walvis bay
# Processing kieta
# Processing lamu
# Processing diamantino
# Processing buala
# Processing shimoda
# Processing cervo
# Processing athabasca
# Processing amapa
# Processing balkhash
# Processing zhangjiakou
# Processing turan
# Processing lakatoro
# Processing santa barbara
# Processing mrakovo
# Processing westport
# Processing lazurne
# Processing henties bay
# Processing berberati
# bentiu does not exist
# Processing naze
# Processing moose factory
# Processing taoudenni
# Processing dubuque
# Processing mount isa
# Processing belgrade
# Processing anchorage
# Processing basco
# Processing wajid
# Processing brookhaven
# Processing hamilton
# Processing sechura
# alappuzha does not exist
# Processing santa rosa
# Processing thinadhoo
# Processing bismarck
# Processing meix-devant-virton
# Processing gweru
# Processing diplo
# Processing lanigan
# Processing libreville
# Processing minab
# Processing ozernovskiy
# Processing fereydun kenar
# Processing chumikan
# Processing magugu
# Processing beisfjord
# Processing barpeta
# Processing ketchikan
# Processing gat
# Processing alyangula
# formoso do araguaia does not exist
# Processing hirado
# Processing mudgee
# Processing caucaia
# Processing bhachau
# Processing caianu mic
# bolshegrivskoye does not exist

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
current_weather["austin"]["wind"]["speed"]
# Out:
# 1.5

# %%
# how to find the city name 
current_weather["austin"]["name"]

# how to find the city cloudiness
current_weather["austin"]["name"]

# how to find the city country
current_weather["austin"]['sys']['country']

# how to find the city date
current_weather["austin"]['dt']

# how to find the city humidity
current_weather["austin"]['main']['humidity']

# how to find the city latitude 
current_weather["austin"]["coord"]['lat']

# how to find the city longitude 
current_weather["austin"]["coord"]['lon']

# how to find the city max temp (currently in Celsius)
# [10(C) x 9/5] + 32 = F
current_weather["austin"]["main"]["temp_max"]

# how to find the city wind speed 
current_weather["austin"]["wind"]["speed"]s
# Out:
# -97.74

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
